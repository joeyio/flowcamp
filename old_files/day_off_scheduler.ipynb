# %% [markdown]
# This is a tool to optimze day off preferences across a department. Future roadmap is to expand to integrate multiple departments.

# %%
import pyomo.environ as pyo
import pandas as pd
import enum as en
import math

# %%
### configurable parameters ###

# valid days for days off
#vd = ['SUN', 'MON', 'TUE', 'WED', 'THU', 'FRI']
vd = [1,2,3,4,5,6]

# minimum number of people that must be at the department (does not include subs)
min_staff = 1

# %% [markdown]
# Sample data format:
#
# | **columns**    | **data type** |
# |----------------|---------------|
# | name           | str           |
# | department     | str           |
# | sub_department | str           |
# | first_choice   | enum          |
# | second_choice  | enum          |
# | third_choice   | enum          |
# | other_people   | str           |
# | days_over_ppl  | boolean       |

# %%
sample_data = pd.DataFrame(data = {'name' : ['bob', 'sally', 'charlie', 'megan', 'alice', 'zach', 'rich', 'john', 'kristen', 'mark'],
                            'department' : pd.Series(['small class']).repeat(10),
                            'sub_department' : ['atv', 'art', 'stem', 'culinary', 'art', 'bikes', 'bikes', 'culinary', 'atv', 'stem'],
                            'first_choice' : [1,3,6,5,1,3,3,4,6,3],
                            'second_choice' : [2,1,1,3,4,5,1,6,1,4],
                            'third_choice' : [4,5,2,6,3,2,4,5,5,1]}).set_index('name')


preference_data = sample_data

preference_data
# Out:
#           department sub_department  first_choice  second_choice  third_choice
# name
# bob      small class            atv             1              2             4
# sally    small class            art             3              1             5
# charlie  small class           stem             6              1             2
# megan    small class       culinary             5              3             6
# alice    small class            art             1              4             3
# zach     small class          bikes             3              5             2
# rich     small class          bikes             3              1             4
# john     small class       culinary             4              6             5
# kristen  small class            atv             6              1             5
# mark     small class           stem             3              4             1

# %%
# derivative tables
max_day_off = pd.DataFrame(preference_data.groupby('sub_department')['first_choice'].count() - min_staff).rename(columns = {'first_choice' : 'max_staff_off'})



for col in vd:
    max_day_off[col] = 0

max_day_off
# Out:
#                 max_staff_off  SUN  MON  TUE  WED  THU  FRI
# sub_department
# art                         1    0    0    0    0    0    0
# atv                         1    0    0    0    0    0    0
# bikes                       1    0    0    0    0    0    0
# culinary                    1    0    0    0    0    0    0
# stem                        1    0    0    0    0    0    0

# %%
# create model

model = pyo.ConcreteModel()

# sets
model.validDays = pyo.Set(initialize = vd)
model.people = pyo.Set(initialize = sample_data.index)

# decision vars
model.D = pyo.Var(model.people, within = model.validDays)

# %%
# objective functions
'''
def prefer(person, assignment) :
    score = 0
    if assignment == preference_data['first_choice'][person] :
        score += 3
    elif assignment == preference_data['second_choice'][person] :
        score += 2
    elif assignment == preference_data['third_choice'][person] :
        score += 1
    else :
        score = 0
    return score
'''

def objective_function(model):
    
    return math.prod((3*int(model.D[p] == preference_data['first_choice'][p]) + 
                     2*int(model.D[p] == preference_data['second_choice'][p]) + 
                     1*int(model.D[p] == preference_data['third_choice'][p])) for p in model.people)
model.score = pyo.Objective(rule = objective_function, sense = pyo.maximize)
# Out:
# WARNING: Implicitly replacing the Component attribute score (type=<class
# 'pyomo.core.base.objective.ScalarObjective'>) on block unknown with a new
# Component (type=<class 'pyomo.core.base.objective.ScalarObjective'>). This is
# usually indicative of a modelling error. To avoid this warning, use
# block.del_component() and block.add_component().
# ERROR: Rule failed when generating expression for Objective score with index
# None: TypeError: int() argument must be a string, a bytes-like object or a
# real number, not 'EqualityExpression'
# ERROR: Constructing component 'score' from data=None failed: TypeError: int()
# argument must be a string, a bytes-like object or a real number, not
# 'EqualityExpression'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 21
#      16 def objective_function(model):
#      18     return math.prod((3*int(model.D[p] == preference_data['first_choice'][p]) +
#      19                      2*int(model.D[p] == preference_data['second_choice'][p]) +
#      20                      1*int(model.D[p] == preference_data['third_choice'][p])) for p in model.people)
# ---> 21 model.score = pyo.Objective(rule = objective_function, sense = pyo.maximize)
#
# File ~/anaconda3/envs/csp/lib/python3.11/site-packages/pyomo/core/base/block.py:610, in _BlockData.__setattr__(self, name, val)
#     601     logger.warning(
#     602         "Implicitly replacing the Component attribute "
#     603         "%s (type=%s) on block %s with a new Component (type=%s)."
#    (...)
#     607         % (name, type(self.component(name)), self.name, type(val))
#     608     )
#     609     self.del_component(name)
# --> 610     self.add_component(name, val)
#     611 else:
#     612     #
#     613     # The incoming value is not a component, so we set the
#    (...)
#     620     # generated while setting the value.
#     621     #
#     622     try:
#
# File ~/anaconda3/envs/csp/lib/python3.11/site-packages/pyomo/core/base/block.py:1185, in _BlockData.add_component(self, name, val)
#    1177     logger.debug(
#    1178         "Constructing %s '%s' on %s from data=%s",
#    1179         val.__class__.__name__,
#    (...)
#    1182         str(data),
#    1183     )
#    1184 try:
# -> 1185     val.construct(data)
#    1186 except:
#    1187     err = sys.exc_info()[1]
#
# File ~/anaconda3/envs/csp/lib/python3.11/site-packages/pyomo/core/base/objective.py:340, in Objective.construct(self, data)
#     337 else:
#     338     # Bypass the index validation and create the member directly
#     339     for index in self.index_set():
# --> 340         ans = self._setitem_when_not_present(index, rule(block, index))
#     341         if ans is not None:
#     342             ans.set_sense(self._init_sense(block, index))
#
# File ~/anaconda3/envs/csp/lib/python3.11/site-packages/pyomo/core/base/initializer.py:435, in ScalarCallInitializer.__call__(self, parent, idx)
#     434 def __call__(self, parent, idx):
# --> 435     return self._fcn(parent)
#
# Cell In[49], line 18, in objective_function(model)
#      16 def objective_function(model):
# ---> 18     return math.prod((3*int(model.D[p] == preference_data['first_choice'][p]) +
#      19                      2*int(model.D[p] == preference_data['second_choice'][p]) +
#      20                      1*int(model.D[p] == preference_data['third_choice'][p])) for p in model.people)
#
# Cell In[49], line 18, in <genexpr>(.0)
#      16 def objective_function(model):
# ---> 18     return math.prod((3*int(model.D[p] == preference_data['first_choice'][p]) +
#      19                      2*int(model.D[p] == preference_data['second_choice'][p]) +
#      20                      1*int(model.D[p] == preference_data['third_choice'][p])) for p in model.people)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'EqualityExpression'

# %%
# subject to
def minimum_staff_rule(model, p) :
    # increase the count of the number of people in the sub-department who have a given day off
    dept = preference_data['sub_department'][p]
    day = model.D[p]
    max_day_off[day][dept] += 1

    return max_day_off[day][dept] <= max_day_off['max_staff_off'][dept]
model.minimum_staff_constraint = pyo.Constraint(model.people, rule = minimum_staff_rule)
# Out:
# ERROR: Rule failed when generating expression for Constraint
# minimum_staff_constraint with index bob: KeyError: None
# ERROR: Constructing component 'minimum_staff_constraint' from data=None
# failed: KeyError: None
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/csp/lib/python3.11/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~/anaconda3/envs/csp/lib/python3.11/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/envs/csp/lib/python3.11/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: None
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 9
#       6     max_day_off[day][dept] += 1
#       8     return max_day_off[day][dept] <= max_day_off['max_staff_off'][dept]
# ----> 9 model.minimum_staff_constraint = pyo.Constraint(model.people, rule = minimum_staff_rule)
#
# File ~/anaconda3/envs/csp/lib/python3.11/site-packages/pyomo/core/base/block.py:580, in _BlockData.__setattr__(self, name, val)
#     575 if name not in self.__dict__:
#     576     if isinstance(val, Component):
#     577         #
#     578         # Pyomo components are added with the add_component method.
#     579         #
# --> 580         self.add_component(name, val)
#     581     else:
#     582         #
#     583         # Other Python objects are added with the standard __setattr__
#     584         # method.
#     585         #
#     586         super(_BlockData, self).__setattr__(name, val)
#
# File ~/anaconda3/envs/csp/lib/python3.11/site-packages/pyomo/core/base/block.py:1185, in _BlockData.add_component(self, name, val)
#    1177     logger.debug(
#    1178         "Constructing %s '%s' on %s from data=%s",
#    1179         val.__class__.__name__,
#    (...)
#    1182         str(data),
#    1183     )
#    1184 try:
# -> 1185     val.construct(data)
#    1186 except:
#    1187     err = sys.exc_info()[1]
#
# File ~/anaconda3/envs/csp/lib/python3.11/site-packages/pyomo/core/base/constraint.py:813, in Constraint.construct(self, data)
#     810     else:
#     811         # Bypass the index validation and create the member directly
#     812         for index in self.index_set():
# --> 813             self._setitem_when_not_present(index, rule(block, index))
#     814 except Exception:
#     815     err = sys.exc_info()[1]
#
# File ~/anaconda3/envs/csp/lib/python3.11/site-packages/pyomo/core/base/initializer.py:313, in IndexedCallInitializer.__call__(self, parent, idx)
#     311     return self._fcn(parent, *idx)
#     312 else:
# --> 313     return self._fcn(parent, idx)
#
# Cell In[33], line 6, in minimum_staff_rule(model, p)
#       4 dept = preference_data['sub_department'][p]
#       5 day = model.D[p]
# ----> 6 max_day_off[day][dept] += 1
#       8 return max_day_off[day][dept] <= max_day_off['max_staff_off'][dept]
#
# File ~/anaconda3/envs/csp/lib/python3.11/site-packages/pandas/core/frame.py:3805, in DataFrame.__getitem__(self, key)
#    3803 if self.columns.nlevels > 1:
#    3804     return self._getitem_multilevel(key)
# -> 3805 indexer = self.columns.get_loc(key)
#    3806 if is_integer(indexer):
#    3807     indexer = [indexer]
#
# File ~/anaconda3/envs/csp/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#    3810     self._check_indexing_error(key)
#
# KeyError: None

# %%
opt = pyo.SolverFactory('glpk')

opt.solve(model)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[23], line 3
#       1 opt = pyo.SolverFactory('glpk')
# ----> 3 opt.solve(model)
#
# File ~/anaconda3/envs/csp/lib/python3.11/site-packages/pyomo/opt/base/solvers.py:548, in OptSolver.solve(self, *args, **kwds)
#     546 if isinstance(arg, _BlockData):
#     547     if not arg.is_constructed():
# --> 548         raise RuntimeError(
#     549             "Attempting to solve model=%s with unconstructed "
#     550             "component(s)" % (arg.name,)
#     551         )
#     553 _model = arg
#     554 # import suffixes must be on the top-level model
#
# RuntimeError: Attempting to solve model=unknown with unconstructed component(s)

# %%
def yeet(a,b):
    return int(a==b)

yeet(5,6) * 2
# Out:
# 0
